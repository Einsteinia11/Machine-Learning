# %%
import numpy as np
import pandas as pd

# %%
weatherdata={
    'day':['19/4/2023','20/4/2023','21/04/2023'],
    'temperature':[32,35,28],
    'event':['rain','sunny','snow']
}
weatherdf=pd.DataFrame(weatherdata)
weatherdf
# Out:
#           day  temperature  event
# 0   19/4/2023           32   rain
# 1   20/4/2023           35  sunny
# 2  21/04/2023           28   snow

# %%
weatherdf.shape
# Out:
# (3, 3)

# %%
rows,columns=weatherdf.shape
print(rows)
print(columns)
# Out:
# 3
# 3

# %%
weatherdf[1:]
# Out:
#           day  temperature  event
# 1   20/4/2023           35  sunny
# 2  21/04/2023           28   snow

# %%
weatherdf.columns
# Out:
# Index(['day', 'temperature', 'event'], dtype='object')

# %%
weatherdf['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# Name: temperature, dtype: int64

# %%
weatherdf.temperature
# Out:
# 0    32
# 1    35
# 2    28
# Name: temperature, dtype: int64

# %%
type(weatherdf['temperature'])
# Out:
# pandas.core.series.Series

# %%
weatherdf['temperature'].max()
# Out:
# 35

# %%
weatherdf['temperature'].mean()
# Out:
# 31.666666666666668

# %%
weatherdf[['temperature','event']]
# Out:
#    temperature  event
# 0           32   rain
# 1           35  sunny
# 2           28   snow

# %%
weatherdf[weatherdf.temperature>30]
# Out:
#          day  temperature  event
# 0  19/4/2023           32   rain
# 1  20/4/2023           35  sunny

# %%
weatherdf[weatherdf.temperature==weatherdf.temperature.max()]
# Out:
#          day  temperature  event
# 1  20/4/2023           35  sunny

# %%
weatherdf['day'][weatherdf.temperature==weatherdf.temperature.max()]
# Out:
# 1    20/4/2023
# Name: day, dtype: object

# %%
weatherdf[['day','temperature']][weatherdf.temperature==weatherdf.temperature.max()]
# Out:
#          day  temperature
# 1  20/4/2023           35

# %%
weatherdf.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
weatherdf.set_index('day',inplace=True)

# %%
weatherdf
# Out:
#             temperature  event
# day
# 19/4/2023            32   rain
# 20/4/2023            35  sunny
# 21/04/2023           28   snow

# %%
weatherdf.loc['20/4/2023']
# Out:
# temperature       35
# event          sunny
# Name: 20/4/2023, dtype: object

# %%
weatherdf.reset_index(inplace=True)
weatherdf
# Out:
#    index         day  temperature  event
# 0      0   19/4/2023           32   rain
# 1      1   20/4/2023           35  sunny
# 2      2  21/04/2023           28   snow

# %%
data=pd.read_csv('matches.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6612\3289350417.py in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
data.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.tail(1)

# %%
data.shape
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.head()

# %%
#Extracting column from data
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
type(data['winner'])
#series has two things i.e index( sometimes self genarated) and values
# Out:
# pandas.core.series.Series

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
type(data[['team1','team2','winner']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['team1','team2','winner']].shape
# Out:
# (636, 3)

# %%
data['winner'].shape
# Out:
# (636,)

# %%
data.iloc[0] #first row with index values as column names
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.iloc[1] #second row
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
data.iloc[1:3]
# Out:
#    id  season    city        date           team1                   team2  \
# 1   2    2017    Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %%
data.iloc[1:11:2] #1 to 11 alternate

# %%
data.iloc[[1,5,6]] #any row using fancy indexing
# Out:
#    id  season       city        date                  team1  \
# 1   2    2017       Pune  2017-04-06         Mumbai Indians
# 5   6    2017  Hyderabad  2017-04-09          Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09  Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 5           0     Sunrisers Hyderabad            0               9
# 6           0          Mumbai Indians            0               4
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
data.iloc[:,[4,5,10]]

# %%
#filtering data on a condition
#row whwre city value is hyderabad

mask=data['city']=='Hyderabad'

# %%
data[mask]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
data[mask].shape
# Out:
# (49, 18)

# %%
data[mask].shape[0]
# Out:
# 49

# %%
def get_city_match_count(city):
    mask=data['city']==city
    return data[mask].shape[0]

# %%
get_city_match_count('Rajkot')
# Out:
# 10

# %%
mask1=data['city']=='Hyderabad'
mask2=data['date']>'2010-01-01'

data[mask1 & mask2]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 244  245    2011  Hyderabad  2011-04-14              Deccan Chargers
# 248  249    2011  Hyderabad  2011-04-16              Deccan Chargers
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 274  275    2011  Hyderabad  2011-05-03        Kolkata Knight Riders
# ...

# %%
data[mask1 & mask2].shape
# Out:
# (42, 18)

# %%
#value_counts()-->gives frequency count
# team with the num of matches it won

data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
# pandas plot function
import matplotlib.pyplot as plt

data['winner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().head().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['toss_decision'].value_counts()
# Out:
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# series operations
myseries=data['winner'].value_counts()
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5],
#       dtype=int64)

# %%
myseries.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
myseries['Mumbai Indians']
# Out:
# 92

# %%
data['team1'].value_counts()
# Out:
# Mumbai Indians                 82
# Kings XI Punjab                77
# Chennai Super Kings            77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team1, dtype: int64

# %%
data['team2'].value_counts()
# Out:
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
#two series can be added index wise
data['team1'].value_counts()+data['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %%
import pandas as pd
import numpy as np 
s=pd.Series(np.array([1,3,40,7,8,8,9]))
print(s.sort_values())
print(s.idxmax())  


#  create a dictionary 
dictionary = {'X' : 50, 'XII' : 25, 'XI' : 30} #  create a series 
series = pd.Series(dictionary) 
print(series)
print(series.sort_index())
series.sort_values()

temp=pd.Series(np.array([25,40,18,27,32,39,28]), index=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
temp
# Out:
# 0     1
# 1     3
# 3     7
# 4     8
# 5     8
# 6     9
# 2    40
# dtype: int32
# 2
# X      50
# XII    25
# XI     30
# dtype: int64
# X      50
# XI     30
# XII    25
# dtype: int64
# Monday       25
# Tuesday      40
# Wednesday    18
# Thursday     27
# Friday       32
# Saturday     39
# Sunday       28
# dtype: int32

# %%
temp.iloc[4]
# Out:
# 32

# %%
temp.loc["Tuesday"]
# Out:
# 40

# %%
exam_dic1  = {'name': ['Aroma', 'Kiran', 'Rayan', 'Rohan', 'Amit', 'Yash', 'Mona', 'Kartik', 'Kavita', 'Pooja'],
        'perc': [79.5, 29, 90.5, np.nan, 32, 65, 56, np.nan, 29, 89],
          'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', np.nan, 'no', np.nan]}
exam_dic2  = {'name': ['Parveen', 'Ahil', 'Akanksha', 'Shruti', 'Hema'],
        'perc': [89.5, 92, 90.5, 91.5, 90],
          'qualify': ['yes', 'yes', 'yes', 'yes', 'yes']}

exam_data1 = pd.DataFrame(exam_dic1)
exam_data2=pd.DataFrame(exam_dic2)

# %%
print(exam_data2)
print(exam_data1)
result_data = pd.concat([exam_data1, exam_data2])
result_data.reset_index(drop=True, inplace=True)
print(result_data)
mask1=result_data['perc']>=80


result_data[mask1]
#print(result_data.isnull())
print(result_data[result_data.isnull().any(axis=1)])
#print(result_data.isna().sum())
# Out:
#        name  perc qualify
# 0   Parveen  89.5     yes
# 1      Ahil  92.0     yes
# 2  Akanksha  90.5     yes
# 3    Shruti  91.5     yes
# 4      Hema  90.0     yes
#      name  perc qualify
# 0   Aroma  79.5     yes
# 1   Kiran  29.0      no
# 2   Rayan  90.5     yes
# 3   Rohan   NaN      no
# 4    Amit  32.0      no
# 5    Yash  65.0     yes
# 6    Mona  56.0     yes
# 7  Kartik   NaN     NaN
# 8  Kavita  29.0      no
# 9   Pooja  89.0     NaN
#         name  perc qualify
# 0      Aroma  79.5     yes
# 1      Kiran  29.0      no
# 2      Rayan  90.5     yes
# 3      Rohan   NaN      no
# 4       Amit  32.0      no
# 5       Yash  65.0     yes
# 6       Mona  56.0     yes
# 7     Kartik   NaN     NaN
# 8     Kavita  29.0      no
# 9      Pooja  89.0     NaN
# 10   Parveen  89.5     yes
# 11      Ahil  92.0     yes
# 12  Akanksha  90.5     yes
# 13    Shruti  91.5     yes
# 14      Hema  90.0     yes
#      name  perc qualify
# 3   Rohan   NaN      no
# 7  Kartik   NaN     NaN
# ...

# %%
df = pd.read_csv("matches.csv")
# Display Name of Columns
print(df.columns)

# Display no of rows and column
print(df.shape)

# Display Column Names and their types
print(df.info())
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')
# (636, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
# ...

# %%
data = np.random.randint(5, 40, size=(12, 3))
df = pd.DataFrame(data, columns=['random_no_1',
                                 'random_no_2',
                                 'random_no_3'])
 
# displaying random integers in the dataframe
print(df)
# Out:
#     random_no_1  random_no_2  random_no_3
# 0            32           29           23
# 1            10           12            7
# 2            17            5            6
# 3            34           12           29
# 4            31            5           23
# 5            15           36            8
# 6            19           22           16
# 7            39           24           23
# 8            15           20           38
# 9            17           36           36
# 10           12           35           36
# 11           20           23           32

# %%
df.iloc[0,4]
# Out:
# 193

# %%
p = 0.2 #percentage missing data required

df = pd.DataFrame(np.random.randint(0,1000,size=(30,6)))
print(df)
maskrow = np.random.randint(0,30,50)
maskcol= np.random.randint(0,6,50)
print(maskrow)
print(maskcol)
# Out:
#       0    1    2    3    4    5
# 0   423  588  392   56  739  930
# 1   477  534  370  445  443  570
# 2    95  544  525   97   78  770
# 3   613  149  229  104  329    1
# 4   499  750  433  933   80  161
# 5   430  352  351  677  363  676
# 6   994  156   26   72  539  426
# 7   235  207  933  964  214  686
# 8   301  280  331  490   76  521
# 9   948  696  789  982  216  867
# 10  973  150  536   62  960  941
# 11  253  307  531  806  609  131
# 12  653  352  321    5  695  844
# 13  988  374  368  244  369  978
# 14  999  398  320   56    3  811
# 15  709  423  805  842  525  313
# 16  665  118  560  100  242  623
# 17  417  267  506  656  290  982
# 18  829  139  732  909  887  246
# 19  260  635  505  830  279  282
# 20  753  923  897  323  826  103
# 21  205  726  801  152  373  638
# 22  415  156  344  714  945  551
# 23  468  720  353  337  616  416
# 24  311  233  891  480  221  306
# 25  158  822  263   26  275  304
# 26   26  312  540  565  256   71
# ...

# %%
for i in range(0,50):
        df.iloc[maskrow[i],maskcol[i]]=np.nan
    
df
# Out:
#         0      1      2      3      4      5
# 0   423.0    NaN  392.0   56.0  739.0  930.0
# 1     NaN  534.0  370.0  445.0  443.0  570.0
# 2    95.0  544.0  525.0   97.0   78.0  770.0
# 3   613.0  149.0  229.0  104.0  329.0    1.0
# 4   499.0  750.0    NaN  933.0   80.0  161.0
# 5   430.0  352.0  351.0  677.0  363.0  676.0
# 6     NaN    NaN   26.0    NaN  539.0    NaN
# 7     NaN  207.0  933.0  964.0    NaN    NaN
# 8   301.0  280.0  331.0  490.0   76.0  521.0
# 9     NaN  696.0  789.0  982.0  216.0  867.0
# 10  973.0  150.0  536.0    NaN  960.0  941.0
# 11  253.0  307.0  531.0  806.0  609.0  131.0
# 12  653.0  352.0    NaN    NaN  695.0  844.0
# 13    NaN    NaN  368.0  244.0  369.0  978.0
# 14  999.0  398.0  320.0   56.0    NaN    NaN
# 15  709.0  423.0  805.0    NaN    NaN    NaN
# 16  665.0  118.0  560.0  100.0    NaN  623.0
# 17  417.0    NaN  506.0  656.0  290.0    NaN
# 18  829.0    NaN  732.0    NaN  887.0    NaN
# 19  260.0  635.0  505.0  830.0    NaN    NaN
# ...

# %%
df.shape
# Out:
# (30, 6)

# %%
df.isnull().sum()
# Out:
# 0     8
# 1    10
# 2     3
# 3     6
# 4     5
# 5     9
# dtype: int64

# %%
df.isna().sum(axis=1)
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     4
# 7     3
# 8     0
# 9     1
# 10    1
# 11    0
# 12    2
# 13    2
# 14    2
# 15    3
# 16    1
# 17    2
# 18    3
# 19    2
# 20    2
# 21    0
# 22    1
# 23    3
# 24    2
# 25    1
# 26    2
# 27    1
# 28    0
# 29    0
# dtype: int64

# %%
df = df[df.isnull().sum(axis=1) <= 3]

# %%
df
# Out:
#         0      1      2      3      4      5
# 0   423.0    NaN  392.0   56.0  739.0  930.0
# 1     NaN  534.0  370.0  445.0  443.0  570.0
# 2    95.0  544.0  525.0   97.0   78.0  770.0
# 3   613.0  149.0  229.0  104.0  329.0    1.0
# 4   499.0  750.0    NaN  933.0   80.0  161.0
# 5   430.0  352.0  351.0  677.0  363.0  676.0
# 7     NaN  207.0  933.0  964.0    NaN    NaN
# 8   301.0  280.0  331.0  490.0   76.0  521.0
# 9     NaN  696.0  789.0  982.0  216.0  867.0
# 10  973.0  150.0  536.0    NaN  960.0  941.0
# 11  253.0  307.0  531.0  806.0  609.0  131.0
# 12  653.0  352.0    NaN    NaN  695.0  844.0
# 13    NaN    NaN  368.0  244.0  369.0  978.0
# 14  999.0  398.0  320.0   56.0    NaN    NaN
# 15  709.0  423.0  805.0    NaN    NaN    NaN
# 16  665.0  118.0  560.0  100.0    NaN  623.0
# 17  417.0    NaN  506.0  656.0  290.0    NaN
# 18  829.0    NaN  732.0    NaN  887.0    NaN
# 19  260.0  635.0  505.0  830.0    NaN    NaN
# 20    NaN    NaN  897.0  323.0  826.0  103.0
# ...

# %%
df.shape
# Out:
# (29, 6)

# %%
normalized_df=(df-df.min())/(df.max()-df.min())

# %%
normalized_df
# Out:
#            0         1         2         3         4         5
# 0   0.362832       NaN  0.231534  0.031283  0.750000  0.950870
# 1        NaN  0.626846  0.200284  0.436913  0.415158  0.582395
# 2   0.000000  0.640268  0.420455  0.074035  0.002262  0.787103
# 3   0.573009  0.110067  0.000000  0.081335  0.286199  0.000000
# 4   0.446903  0.916779       NaN  0.945777  0.004525  0.163767
# 5   0.370575  0.382550  0.173295  0.678832  0.324661  0.690890
# 7        NaN  0.187919  1.000000  0.978102       NaN       NaN
# 8   0.227876  0.285906  0.144886  0.483837  0.000000  0.532242
# 9        NaN  0.844295  0.795455  0.996872  0.158371  0.886387
# 10  0.971239  0.111409  0.436080       NaN  1.000000  0.962129
# 11  0.174779  0.322148  0.428977  0.813347  0.602941  0.133060
# 12  0.617257  0.382550       NaN       NaN  0.700226  0.862845
# 13       NaN       NaN  0.197443  0.227320  0.331448  1.000000
# 14  1.000000  0.444295  0.129261  0.031283       NaN       NaN
# ...
